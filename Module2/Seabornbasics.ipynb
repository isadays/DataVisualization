# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('clean_dd.csv')

# %%
df
# Out:
#               NAME  LATITUDE  LONGITUDE  ELEVATION        DATE  DAPR  DASF  \
# 0      ALTA, UT US   40.5905  -111.6369     2660.9  1980-01-01   NaN   NaN
# 1      ALTA, UT US   40.5905  -111.6369     2660.9  1980-01-02   NaN   NaN
# 2      ALTA, UT US   40.5905  -111.6369     2660.9  1980-01-03   NaN   NaN
# 3      ALTA, UT US   40.5905  -111.6369     2660.9  1980-01-04   NaN   NaN
# 4      ALTA, UT US   40.5905  -111.6369     2660.9  1980-01-05   NaN   NaN
# ...            ...       ...        ...        ...         ...   ...   ...
# 14155  ALTA, UT US   40.5905  -111.6369     2660.9  2019-09-03   NaN   NaN
# 14156  ALTA, UT US   40.5905  -111.6369     2660.9  2019-09-04   NaN   NaN
# 14157  ALTA, UT US   40.5905  -111.6369     2660.9  2019-09-05   NaN   NaN
# 14158  ALTA, UT US   40.5905  -111.6369     2660.9  2019-09-06   NaN   NaN
# 14159  ALTA, UT US   40.5905  -111.6369     2660.9  2019-09-07   NaN   NaN
#
#        MDPR  MDSF  PRCP  ...  SNWD  TMAX  TMIN  TOBS  WT01  WT03  WT04  WT05  \
# 0       NaN   NaN  0.10  ...  29.0  38.0  25.0  25.0   NaN   NaN   NaN   NaN
# 1       NaN   NaN  0.43  ...  34.0  27.0  18.0  18.0   NaN   NaN   NaN   NaN
# 2       NaN   NaN  0.09  ...  30.0  27.0  12.0  18.0   NaN   NaN   NaN   NaN
# 3       NaN   NaN  0.00  ...  30.0  31.0  18.0  27.0   NaN   NaN   NaN   NaN
# 4       NaN   NaN  0.00  ...  30.0  34.0  26.0  34.0   NaN   NaN   NaN   NaN
# ...     ...   ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 14155   NaN   NaN  0.01  ...   0.0  74.0  57.0  73.0   NaN   NaN   NaN   NaN
# 14156   NaN   NaN  0.00  ...   0.0  77.0  52.0  74.0   NaN   NaN   NaN   NaN
# 14157   NaN   NaN  0.00  ...   0.0  76.0  54.0  65.0   NaN   NaN   NaN   NaN
# 14158   NaN   NaN  0.07  ...   0.0  66.0  52.0  60.0   NaN   NaN   NaN   NaN
# 14159   NaN   NaN  0.00  ...   0.0  68.0  45.0  64.0   NaN   NaN   NaN   NaN
#
#        WT06  WT11
# 0       NaN   NaN
# 1       NaN   NaN
# 2       NaN   NaN
# 3       NaN   NaN
# 4       NaN   NaN
# ...     ...   ...
# 14155   NaN   NaN
# 14156   NaN   NaN
# 14157   NaN   NaN
# 14158   NaN   NaN
# 14159   NaN   NaN
#
# [14160 rows x 21 columns]

# %%
#Plot a histogram of snow depth
sns.histplot(data=df,x='SNWD')
# Out:
# <Axes: xlabel='SNWD', ylabel='Count'>
